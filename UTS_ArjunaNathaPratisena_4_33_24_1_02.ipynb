# %% [markdown]
# <a href="https://colab.research.google.com/github/JunetzMasihBelajar/2025_AI_TI1B/blob/main/UTS_ArjunaNathaPratisena_4_33_24_1_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UTS Kecerdasan Buatan

# %% [markdown]
# ## Data Load and Preview

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('airbnb.csv')

# Data Preview
print("Dataset shape:", df.shape)
print("\nFirst 5 rows:")
display(df.head())
print("\nData types and missing values:")
display(df.info())
print("\nDescriptive statistics:")
display(df.describe(include='all'))
# Out:
# Dataset shape: (48895, 16)
#
# First 5 rows:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ## Cleaning Data

# %%
### 2. Data Cleaning
print("\n=== DATA CLEANING ===")

# Convert price to numeric
df['price'] = df['price'].astype(str).str.replace('$', '').str.replace(',', '').astype(float)

# Handle missing values
print("\nHandling missing values:")
num_cols = ['reviews_per_month', 'calculated_host_listings_count']
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())
    print(f"Filled missing values in {col} with median: {df[col].median():.2f}")

# Convert and handle datetime
df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')
print(f"\nConverted 'last_review' to datetime. Missing values: {df['last_review'].isna().sum()}")

# Remove extreme price outliers
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['price'] >= (Q1 - 1.5 * IQR)) & (df['price'] <= (Q3 + 1.5 * IQR))].copy()
print(f"\nRemoved price outliers. New shape: {df.shape}")

# Create year column from reviews
df['review_year'] = df['last_review'].dt.year
df['review_year'] = df['review_year'].fillna('No review')
print("\nCreated 'review_year' column")
# Out:
# === DATA CLEANING ===
#
# Handling missing values:
# Filled missing values in reviews_per_month with median: 0.72
# Filled missing values in calculated_host_listings_count with median: 1.00
#
# Converted 'last_review' to datetime. Missing values: 8874
#
# Removed price outliers. New shape: (44670, 17)
#
# Created 'review_year' column

# %%
### Cleaned Data Summary
print("\n=== CLEANED DATA SUMMARY ===")
print("\nDescriptive statistics for numerical columns:")
display(df.describe())

print("\nCategorical value counts:")
print("\nNeighborhood groups:")
display(df['neighbourhood_group'].value_counts())

print("\nRoom types:")
display(df['room_type'].value_counts())

print("\nReview years:")
display(df['review_year'].value_counts())
# Out:
# === CLEANED DATA SUMMARY ===
#
# Descriptive statistics for numerical columns:
#                  id       host_id      latitude     longitude         price  \
# count  4.467000e+04  4.467000e+04  44670.000000  44670.000000  44670.000000
# mean   1.883164e+07  6.585660e+07     40.728261    -73.950098    114.772510
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.414362e+06  7.731978e+06     40.688850    -73.981270     65.000000
# 50%    1.942798e+07  3.028359e+07     40.721245    -73.953865    100.000000
# 75%    2.874070e+07  1.046900e+08     40.763548    -73.933323    150.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990    290.000000
# std    1.088860e+07  7.710895e+07      0.055653      0.046557     61.492409
#
#        minimum_nights  number_of_reviews                    last_review  \
# count    44670.000000       44670.000000                          36045
# ...

# %% [markdown]
# ## Exploratory Data

# %%
# Numerical analysis
num_stats = df.describe()
print("Numerical statistics:")
display(num_stats)

# Categorical analysis
cat_cols = ['neighbourhood_group', 'neighbourhood', 'room_type']
for col in cat_cols:
    print(f"\n{col} value counts:")
    display(df[col].value_counts())

# Price analysis
print("\nPrice analysis:")
print(f"Average price: ${df['price'].mean():.2f}")
print(f"Median price: ${df['price'].median():.2f}")
print(f"Minimum price: ${df['price'].min():.2f}")
print(f"Maximum price: ${df['price'].max():.2f}")
print(f"Price standard deviation: ${df['price'].std():.2f}")

# Price comparison by room type
print("\nPrice by room type:")
display(df.groupby('room_type')['price'].describe())

# Price comparison by neighborhood group
print("\nPrice by neighborhood group:")
display(df.groupby('neighbourhood_group')['price'].describe())
# Out:
# Numerical statistics:
#                  id       host_id      latitude     longitude         price  \
# count  4.592300e+04  4.592300e+04  45923.000000  45923.000000  45923.000000
# mean   1.889853e+07  6.632693e+07     40.728488    -73.950733    119.970320
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.436180e+06  7.724081e+06     40.689235    -73.981925     65.000000
# 50%    1.952568e+07  3.028359e+07     40.721770    -73.954370    100.000000
# 75%    2.891256e+07  1.055068e+08     40.763390    -73.934315    159.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990    334.000000
# std    1.091922e+07  7.755778e+07      0.055331      0.046471     68.150148
#
#        minimum_nights  number_of_reviews                    last_review  \
# count    45923.000000       45923.000000                          36911
# mean         6.938070          23.942665  2018-10-02 17:43:45.656308736
# ...

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

### 1. Price Analysis Visualizations
print("\n=== PRICE ANALYSIS VISUALIZATIONS ===")

plt.figure(figsize=(15, 10))

# Price distribution
plt.subplot(2, 2, 1)
sns.histplot(df['price'], bins=50, kde=True)
plt.title('Distribution of Prices')
plt.xlabel('Price ($)')
plt.ylabel('Frequency')

# Price by room type
plt.subplot(2, 2, 2)
sns.boxplot(x='room_type', y='price', data=df)
plt.title('Price by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Price ($)')
plt.xticks(rotation=45)

# Price by neighborhood group
plt.subplot(2, 2, 3)
sns.boxplot(x='neighbourhood_group', y='price', data=df)
plt.title('Price by Neighborhood Group')
plt.xlabel('Neighborhood Group')
plt.ylabel('Price ($)')
plt.xticks(rotation=45)

# Price trends over time
plt.subplot(2, 2, 4)
price_trend = df[df['review_year'] != 'No review'].groupby('review_year')['price'].mean()
sns.lineplot(x=price_trend.index, y=price_trend.values)
plt.title('Average Price by Review Year')
plt.xlabel('Year')
plt.ylabel('Average Price ($)')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

### 2. Geographic Visualizations
print("\n=== GEOGRAPHIC VISUALIZATIONS ===")

plt.figure(figsize=(15, 12))

# Basic location plot
plt.subplot(2, 2, 1)
sns.scatterplot(x='longitude', y='latitude', data=df, alpha=0.5)
plt.title('Geographic Distribution of Listings')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Location by neighborhood group
plt.subplot(2, 2, 2)
sns.scatterplot(x='longitude', y='latitude', hue='neighbourhood_group',
                data=df, alpha=0.5, palette='viridis')
plt.title('Listings by Neighborhood Group')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Location sized by price
plt.subplot(2, 2, 3)
sns.scatterplot(x='longitude', y='latitude', size='price',
                data=df, alpha=0.5, sizes=(20, 200))
plt.title('Listings Sized by Price')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Location by room type
plt.subplot(2, 2, 4)
sns.scatterplot(x='longitude', y='latitude', hue='room_type',
                data=df, alpha=0.5, palette='Set2')
plt.title('Listings by Room Type')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

### 3. Advanced Visualizations
print("\n=== ADVANCED VISUALIZATIONS ===")

# Density and price combined plot
plt.figure(figsize=(12, 10))
sns.kdeplot(x='longitude', y='latitude', data=df, cmap='Reds', shade=True, alpha=0.3)
scatter = plt.scatter(x=df['longitude'], y=df['latitude'], c=df['price'],
                     cmap='viridis', alpha=0.7, s=20)
plt.colorbar(scatter, label='Price ($)')
plt.title('Airbnb Listings Density and Price Distribution')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# Review analysis
plt.figure(figsize=(15, 5))

# Reviews over time
plt.subplot(1, 2, 1)
review_counts = df[df['review_year'] != 'No review']['review_year'].value_counts().sort_index()
sns.lineplot(x=review_counts.index, y=review_counts.values)
plt.title('Reviews Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=45)

# Reviews vs price
plt.subplot(1, 2, 2)
sns.scatterplot(x='number_of_reviews', y='price', data=df, alpha=0.5)
plt.title('Price vs Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Price ($)')

plt.tight_layout()
plt.show()
# Out:
# === PRICE ANALYSIS VISUALIZATIONS ===
# === GEOGRAPHIC VISUALIZATIONS ===
# === ADVANCED VISUALIZATIONS ===
# <ipython-input-34-4d3b1cadbb43>:91: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='longitude', y='latitude', data=df, cmap='Reds', shade=True, alpha=0.3)
