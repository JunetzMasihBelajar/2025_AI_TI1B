# %% [markdown]
# <a href="https://colab.research.google.com/github/JunetzMasihBelajar/2025_AI_TI1B/blob/main/UTS_ArjunaNathaPratisena_4.33.24.1.02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UTS Kecerdasan Buatan

# %% [markdown]
# ## Data Load and Preview

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('airbnb.csv')

# %% [markdown]
# ### Menampilkan 5 data pertama

# %%
print("\nFirst 5 rows:")
display(df.head())
# Out:
# First 5 rows:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Menampilkan 5 data terakhir

# %%
display(df.tail())
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# ### Mengetahui jumlah baris dan kolom data

# %%
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (48895, 16)

# %% [markdown]
# ### Mengetahui tipe data dari setiap kolom

# %%
print("Data types:")
display(df.info())
# Out:
# Data types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ### Mengetahui jumlah null values dari setiap kolom

# %%
print(df.isnull().sum())
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ### Mengetahui jumlah data, mean, median, standart deviasi, nilai minimal dan maksimal dari data

# %%
display(df.describe(include='all'))
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Mengapus nilai NaN dari dataset

# %%
df.dropna(how='any', inplace=True)

# %% [markdown]
# ### Mengecek jumlah nilai NaN setelah penghapusan nilai NaN

# %%
print(df.isnull().sum())
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ### Menghapus data yang memiliki price 0

# %%
df = df.drop(index=df[df['price'] == 0].index)

df.shape
# Out:
# (38811, 16)

# %% [markdown]
# ### Pengecekan kembali setelah cleaning data

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38811 entries, 0 to 48852
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38811 non-null  int64
#  1   name                            38811 non-null  object
#  2   host_id                         38811 non-null  int64
#  3   host_name                       38811 non-null  object
#  4   neighbourhood_group             38811 non-null  object
#  5   neighbourhood                   38811 non-null  object
#  6   latitude                        38811 non-null  float64
#  7   longitude                       38811 non-null  float64
#  8   room_type                       38811 non-null  object
#  9   price                           38811 non-null  int64
#  10  minimum_nights                  38811 non-null  int64
#  11  number_of_reviews               38811 non-null  int64
# ...

# %%
display(df.describe(include='all'))
# Out:
#                   id                 name       host_id host_name  \
# count   3.881100e+04                38811  3.881100e+04     38811
# unique           NaN                38243           NaN      9884
# top              NaN  Home away from home           NaN   Michael
# freq             NaN                   12           NaN       335
# mean    1.810018e+07                  NaN  6.424611e+07       NaN
# std     1.069502e+07                  NaN  7.590371e+07       NaN
# min     2.539000e+03                  NaN  2.438000e+03       NaN
# 25%     8.720894e+06                  NaN  7.028184e+06       NaN
# 50%     1.887173e+07                  NaN  2.837092e+07       NaN
# 75%     2.756998e+07                  NaN  1.018872e+08       NaN
# max     3.645581e+07                  NaN  2.738417e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                38811         38811  38811.000000  38811.000000
# ...

# %% [markdown]
# ## Data Analysis and Visualization

# %% [markdown]
# ### Mengetahui harga tertinggi

# %%
df1 = df.sort_values(by='price', ascending=False)
df1.head()
# Out:
#              id                                               name   host_id  \
# 9151    7003697                Furnished room in Astoria apartment  20582832
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown   3906464
# 6530    4737930                                 Spanish Harlem Apt   1235070
# 30268  23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho  18128455
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 12342       Amy           Manhattan  Lower East Side  40.71355  -73.98507
# 6530      Olson           Manhattan      East Harlem  40.79264  -73.93898
# 30268       Rum           Manhattan          Tribeca  40.72197  -74.00633
#
# ...

# %% [markdown]
# ### Mengetahui harga terendah

# %%
df1 = df.sort_values(by='price', ascending=True)
df1.head()
# Out:
#              id                                           name    host_id  \
# 22835  18490141                        IT'S SIMPLY CONVENIENT!   97001292
# 35386  28071998             Cozy room in a three-bedroom House   47516406
# 27972  21869057  Spacious 2-bedroom Apt in Heart of Greenpoint   11967922
# 47218  35642891                     Beautiful room in Bushwick  268138154
# 35601  28270998   Charming, bright and brand new Bed-Stuy home     647528
#
#                host_name neighbourhood_group       neighbourhood  latitude  \
# 22835              Maria              Queens             Jamaica  40.69085
# 35386             Arthur              Queens           Woodhaven  40.69139
# 27972  Vishanti & Jeremy            Brooklyn          Greenpoint  40.72421
# 47218              Julio            Brooklyn            Bushwick  40.69640
# 35601           Caterina            Brooklyn  Bedford-Stuyvesant  40.69508
#
# ...

# %% [markdown]
# ### Perbandingan tipe ruangan AirBnb

# %%
# Membuat dataframe untuk menghitung jumlah tipe ruangan
room_count_df = df['room_type'].value_counts().reset_index()
room_count_df.columns = ['room_type', 'count']

# Membuat pie chart dengan df.plot()
plt.figure(figsize=(8, 8))
room_count_df.plot(
    kind='pie',
    y='count',
    labels=room_count_df['room_type'],
    autopct='%.2f%%',
    legend=False,
    colors=['#ff9999','#66b3ff','#99ff99'],
    textprops={'fontsize': 10},
    startangle=90,
    shadow=True,
    title='Rasio Tipe Ruangan AirBnb di New York City',
    ylabel=''  # Menghilangkan label y yang tidak perlu
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Menghitung jumlah listing AirBnb yang ada di setiap neighbourhood berdasarkan tipe ruangan

# %%
neighbourhood_df = df[['neighbourhood_group','neighbourhood','room_type','price','minimum_nights']]

plt.figure(figsize=(10,6))
sns.set(style="whitegrid", color_codes=True)
font_title = {'size': 15}
font_label = {'size': 12}
sns.countplot(
    x='neighbourhood_group',
    data=df,
    hue='room_type',
    palette='dark:yellow'  # Gradien dari dark ke yellow
)
plt.xlabel('Neighbourhood_group',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Jumlah listing AirBnb yang ada di setiap neighbourhood berdasarkan tipe ruangan ",fontdict=font_title,fontweight='bold')
plt.show()

# %% [markdown]
# ### Mengetahui koordinat lokasi seluruh listing AirBnb yang ada di New York City

# %%
lokasi_airbnb = df.sort_values(by='price',ascending=False)

#Plotting Scatterplot
plt.figure(figsize=(10,6))
sns.set(style="whitegrid", color_codes=True)
font_title = {'size': 15}
font_label = {'size': 12}
sns.scatterplot(data=lokasi_airbnb,x='longitude',y='latitude',hue='neighbourhood_group')
plt.xlabel('Longitude',fontdict=font_label,fontweight='bold')
plt.ylabel('Latitude',fontdict=font_label,fontweight='bold')
plt.title("Lokasi Seluruh listing AirBnb yang ada di kota New York City",fontweight='bold',fontdict=font_title)
plt.show()

# %% [markdown]
# ### Mengetahui lokasi 1000 listing AirBnb dengan harga tertinggi di kota New York City

# %%
lokasi_airbnb = df.sort_values(by='price',ascending=False)[:1000]

#Plotting Scatterplot
plt.figure(figsize=(10,6))
sns.set(style="whitegrid", color_codes=True)
font_title = {'size': 15}
font_label = {'size': 12}
sns.scatterplot(data=lokasi_airbnb,x='longitude',y='latitude',hue='neighbourhood_group')
plt.xlabel('Longitude',fontdict=font_label,fontweight='bold')
plt.ylabel('Latitude',fontdict=font_label,fontweight='bold')
plt.title("1000 Lokasi listing AirBnb dengan harga tertinggi di kota New York City",fontweight='bold',fontdict=font_title)
plt.show()

# %% [markdown]
# ### Mengetahui variasi harga listing berdasarkan tipe ruangan di setiap neighbourhood

# %%
plt.figure(figsize=(10,6))
sns.set(style="whitegrid", color_codes=True)
font_title = {'size': 15}
font_label = {'size': 12}
sns.barplot(x = 'neighbourhood_group',y = 'price',hue='room_type',palette = "BuGn_r",data = neighbourhood_df)
plt.xlabel('Neighbourhood_group',fontdict=font_label,fontweight='bold')
plt.ylabel('Price',fontdict=font_label,fontweight='bold')

plt.title("Variasi harga berdasarkan tipe ruangan di setiap neighbourhood",fontweight='bold',fontdict=font_title)
plt.show()

# %% [markdown]
# ### Mengetahui rentang harga di setiap neighbourhood

# %%
# Membuat dataframe rentang harga berdasarkan lokasi AirBnb
Queens_Price_df=neighbourhood_df.loc[neighbourhood_df['neighbourhood_group']=='Queens',['neighbourhood_group','price']]
Manhattan_Price_df=neighbourhood_df.loc[neighbourhood_df['neighbourhood_group']=='Manhattan',['neighbourhood_group','price']]
Brooklyn_Price_df=neighbourhood_df.loc[neighbourhood_df['neighbourhood_group']=='Brooklyn',['neighbourhood_group','price']]
Bronx_Price_df=neighbourhood_df.loc[neighbourhood_df['neighbourhood_group']=='Bronx',['neighbourhood_group','price']]
Staten_Island_Price_df=neighbourhood_df.loc[neighbourhood_df['neighbourhood_group']=='Staten Island',['neighbourhood_group','price']]

# %%
# Rentang harga di Queens

plt.figure(figsize=(15,12))
plt.xlabel('Price',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Rentang harga di Queens",fontdict=font_title,fontweight='bold')
sns.histplot(data=Queens_Price_df, x="price", log_scale=True,color='green')

# Rentang harga di Brooklyn

plt.figure(figsize=(15,12))
plt.xlabel('Price',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Rentang harga di Brooklyn",fontdict=font_title,fontweight='bold')
sns.histplot(data=Brooklyn_Price_df, x="price", log_scale=True,color='green')


# Rentang harga di Bronx

plt.figure(figsize=(15,12))
plt.xlabel('Price',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Rentang harga di Bronx",fontdict=font_title,fontweight='bold')
sns.histplot(data=Bronx_Price_df, x="price", log_scale=True,color='green')


# Rentang harga di Staten island

plt.figure(figsize=(15,12))
plt.xlabel('Price',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Rentang harga di Staten island",fontdict=font_title,fontweight='bold')
sns.histplot(data=Staten_Island_Price_df, x="price", log_scale=True,color='green')


# Rentang harga di Manhattan

plt.figure(figsize=(15,12))
plt.xlabel('Price',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Rentang harga di Manhattan",fontdict=font_title,fontweight='bold')
sns.histplot(data=Manhattan_Price_df, x="price", log_scale=True,color='green')
# Out:
# <Axes: title={'center': 'Rentang harga di Manhattan'}, xlabel='Price', ylabel='Count'>

# %% [markdown]
# ### Menampilkan harga

# %%
#Menampilkan histogram dan boxplot
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

# Histogram Harga
axs[0].hist(df['price'], bins=50, color='skyblue', edgecolor='black')
axs[0].set_title('Distribusi Harga Airbnb')
axs[0].set_xlabel('Harga')
axs[0].set_ylabel('Jumlah')

# Boxplot Harga
sns.boxplot(data=df, y='price', ax=axs[1])
axs[1].set_title('Boxplot Harga')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Menghitung harga rata-rata harga di setiap neighbourhood

# %%
avg_price = df.groupby('neighbourhood_group')['price'].mean().reset_index()
avg_price

# Bar chart rata-rata harga
plt.figure(figsize=(8, 5))
sns.barplot(
    data=avg_price,
    x='neighbourhood_group',
    y='price',
    hue='neighbourhood_group',
    palette='viridis',
    legend=False
)

plt.title('Harga Rata-Rata Airbnb per Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Harga Rata-Rata')
plt.show()

# %% [markdown]
# ### Heatmap Korelasi

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap Korelasi Fitur Numerik')
plt.show()
